# %%
import tensorflow as tf

print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))

# %% [markdown]
# # Dataset Exploration
#
# ## Dataset Summary
#
# - Categories: 6
# - Landmarks: 30
# - Images: 420
#
# ### Categories
# - Gothic
# - Modern
# - Mughal
# - Neoclassical
# - Pagodas
# - Pyramids
#
# ### Objective
# Build a landmark recognition system using transfer learning with EfficientNetB0.

# %%
import os

dataset_path = "/kaggle/input/YOUR_DATASET_NAME"

categories = os.listdir(dataset_path)

print("Number of Categories:", len(categories))
print("\nCategories:\n")

for category in categories:
    print(category)

# %%
import os

print(os.listdir('/kaggle/input'))

# %%
import os

dataset_path = "/kaggle/input/datasets"

categories = os.listdir(dataset_path)

print("Number of Categories:", len(categories))
print("\nCategories:")

for category in categories:
    print(category)

# %%
import os

dataset_path = "/kaggle/input/datasets/kayvanshah"

categories = os.listdir(dataset_path)

print("Number of Categories:", len(categories))
print("\nCategories:")

for category in categories:
    print(category)

# %%
import os

path = "/kaggle/input/datasets"

for root, dirs, files in os.walk(path):
    print(root)
    if root.count("/") > 8:  # prevent printing too much
        continue

# %%
import os

dataset_path = "/kaggle/input/datasets/kayvanshah/landmarks-dataset"

total_categories = 0
total_landmarks = 0
total_images = 0

for category in os.listdir(dataset_path):

    category_path = os.path.join(dataset_path, category)

    if os.path.isdir(category_path):

        total_categories += 1

        landmarks = os.listdir(category_path)

        print(f"\n{category}")

        for landmark in landmarks:

            landmark_path = os.path.join(category_path, landmark)

            image_count = len(os.listdir(landmark_path))

            total_landmarks += 1
            total_images += image_count

            print(f"   {landmark}: {image_count} images")

print("\n--------------------")
print("Categories:", total_categories)
print("Landmarks:", total_landmarks)
print("Images:", total_images)

# %%
import tensorflow as tf

dataset_path = "/kaggle/input/datasets/kayvanshah/landmarks-dataset"

train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=16
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=(224, 224),
    batch_size=16
)

print("Class Names:")
print(train_ds.class_names)

# %%
print(train_ds.class_names)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))

for images, labels in train_ds.take(1):

    for i in range(9):

        ax = plt.subplot(3, 3, i + 1)

        plt.imshow(images[i].numpy().astype("uint8"))

        plt.title(train_ds.class_names[labels[i]])

        plt.axis("off")

plt.show()
